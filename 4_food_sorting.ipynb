# %%
import src

# %%
image="potato.jpg"

# %%
src.show_image(image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=186x120>

# %%
src.ask_image(image,"What is this?",number_of_results=1)
# Out:
# ['potato']

# %%
image="rock1.jpg"

# %%
src.show_image(image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=186x137>

# %%
src.ask_image(image,"What is this?",number_of_results=1)
# Out:
# ['potato']

# %%
image="rock2.jpg"

# %%
src.show_image(image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=259x194>

# %%
src.ask_image(image,"What is this?",number_of_results=1)
# Out:
# ['rock']

# %%
image="almonds3.jpg"

# %%
src.show_image(image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=285x128>

# %%
src.ask_image(image,"What is this?",number_of_results=1)
# Out:
# ['almonds']

# %%
src.ask_image(image,"Are the items in the image good or bad quality?",number_of_results=2)
# Out:
# ['good', 'good quality']

# %%
image="almonds4.jpg"

# %%
src.show_image(image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=436x218>

# %%
src.ask_image(image,"What is this?",number_of_results=1)
# Out:
# ['almonds']

# %%
src.ask_image(image,"Are the items in the image good or bad quality?",number_of_results=2)
# Out:
# ['good', 'bad']
